# %%
import pandas as pd
import numpy as np

# import seaborn as sns
# import plotly.express as px
import matplotlib.pyplot as plt
import missingno as msno

# %%
excel_file_dir = 'local_settings\compras,_estoque_e_producao_318635218276261.xlsx'

# %%
df_data = pd.read_excel(excel_file_dir)

# %%
df_data
# Out:
#      Situação                                          Descrição  \
# 0     Inativo  TCOMPHP7553X/5949X - TONER COMPATIVEL HP 7553X...
# 1     Inativo  MACHO MAQ.HSS-E,M,6H,C.HEL,DIN371,GS M4X0.7-6H-63
# 2     Inativo  Toner para Brother TN-2370 | HL-L2320D | HL-L2...
# 3     Inativo  MACHO MAQ.HSS-E,M,6H,C.HEL,DIN371,GS,OX M4X0.7...
# 4     Inativo  (INATIVO) TUBO DE SILICONE 10,00 X 06,00MM 60 ...
# ...       ...                                                ...
# 4514  Inativo  01040015 RL.LA ATLAS VELUDO S/CABO 329/5 23CM ...
# 4515    Ativo  TOMADA BARRA PADRAO BRASIL 2P+T 10A QUINTUPLA ...
# 4516  Inativo                          CELULA DE CARGA SPF1-30KG
# 4517  Inativo                  Coluna PLavat Diamantina Br Icasa
# 4518    Ativo            Lavat PColuna Diamantina 56x46Cm Br Ica
#
#                   Código              Família de Produto  Código NCM  \
# 0     TCOMPHP7553X/5949X                             NaN  8443.99.32
# ...

# %%
df_data.columns
# Out:
# Index(['Situação', 'Descrição', 'Código', 'Família de Produto', 'Código NCM',
#        'CEST', 'Código EAN (GTIN)', 'Preço Unitário de Venda',
#        'Estoque Disponível', 'Unidade', 'Custo Médio Contábil',
#        'Estoque Mínimo', 'Peso Líquido', 'Peso Bruto', 'Altura', 'Largura',
#        'Profundidade', 'Marca', 'Dias de Garantia', 'Dias de Crossdocking',
#        'Cupom Fiscal (PDV)', 'Marketplace', 'Tipo do Item (Bloco K)',
#        'Origem da Mercadoria', 'Preço Tabelado (Pauta)',
#        'Produzido em Escala Relevante', 'CNPJ Fabricante', 'Características',
#        'Inclusão', 'Última Alteração', 'Incluído por', 'Alterado por'],
#       dtype='object')

# %%
df_data.count()
# Out:
# Situação                         4519
# Descrição                        4519
# Código                           4519
# Família de Produto               4311
# Código NCM                       4519
# CEST                             1345
# Código EAN (GTIN)                 196
# Preço Unitário de Venda          4519
# Estoque Disponível               4519
# Unidade                          4519
# Custo Médio Contábil             4519
# Estoque Mínimo                   4519
# Peso Líquido                     4519
# Peso Bruto                       4519
# Altura                           4519
# Largura                          4519
# Profundidade                     4519
# Marca                              42
# Dias de Garantia                 4519
# Dias de Crossdocking             4519
# Cupom Fiscal (PDV)               4519
# Marketplace                      4519
# Tipo do Item (Bloco K)           4519
# Origem da Mercadoria             1379
# Preço Tabelado (Pauta)              3
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4519 entries, 0 to 4518
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Situação                       4519 non-null   object
#  1   Descrição                      4519 non-null   object
#  2   Código                         4519 non-null   object
#  3   Família de Produto             4311 non-null   object
#  4   Código NCM                     4519 non-null   object
#  5   CEST                           1345 non-null   object
#  6   Código EAN (GTIN)              196 non-null    object
#  7   Preço Unitário de Venda        4519 non-null   float64
#  8   Estoque Disponível             4519 non-null   float64
#  9   Unidade                        4519 non-null   object
#  10  Custo Médio Contábil           4519 non-null   float64
#  11  Estoque Mínimo                 4519 non-null   int64
# ...

# %%
print(f'Any NaN values? {df_data.isna().values.sum()}')
# Out:
# Any NaN values? 32959

# %%
print(f'Any duplicates? {df_data.duplicated().values.sum()}')
# Out:
# Any duplicates? 0

# %%
print("There are {}".format(df_data.isna().sum().sum()), "missing values left in the dataframe")
# Out:
# There are 32959 missing values left in the dataframe

# %%
msno.matrix(df_data, color=(0.18823, 0.69804, 0.549019))
# Out:
# <AxesSubplot:>

# %%
msno.bar(df_data, log=True)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(df_data, figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
clean = df_data

# %%
# col_subset_delete = ['Situação', 'Descrição', 'Código', 'Família de Produto', 'Código NCM',
#        'CEST', 'Código EAN (GTIN)', 'Preço Unitário de Venda',
#        'Estoque Disponível', 'Unidade', 'Custo Médio Contábil',
#        'Estoque Mínimo', 'Peso Líquido', 'Peso Bruto', 'Altura', 'Largura',
#        'Profundidade', 'Marca', 'Dias de Garantia', 'Dias de Crossdocking',
#        'Cupom Fiscal (PDV)', 'Marketplace', 'Tipo do Item (Bloco K)',
#        'Origem da Mercadoria', 'Preço Tabelado (Pauta)',
#        'Produzido em Escala Relevante', 'CNPJ Fabricante', 'Características',
#        'Inclusão', 'Última Alteração', 'Incluído por', 'Alterado por']

col_subset_delete = ['CEST', 'Código EAN (GTIN)', 'Preço Unitário de Venda',
       'Marca', 'Dias de Garantia', 'Dias de Crossdocking',
       'Cupom Fiscal (PDV)', 'Marketplace', 'Tipo do Item (Bloco K)',
       'Origem da Mercadoria', 'Preço Tabelado (Pauta)',
       'Produzido em Escala Relevante', 'CNPJ Fabricante', 'Características',]

# %%
clean = clean.drop(axis=1, labels=col_subset_delete)

# %%
msno.matrix(clean)
# Out:
# <AxesSubplot:>

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4519 entries, 0 to 4518
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Situação              4519 non-null   object
#  1   Descrição             4519 non-null   object
#  2   Código                4519 non-null   object
#  3   Família de Produto    4311 non-null   object
#  4   Código NCM            4519 non-null   object
#  5   Estoque Disponível    4519 non-null   float64
#  6   Unidade               4519 non-null   object
#  7   Custo Médio Contábil  4519 non-null   float64
#  8   Estoque Mínimo        4519 non-null   int64
#  9   Peso Líquido          4519 non-null   float64
#  10  Peso Bruto            4519 non-null   float64
#  11  Altura                4519 non-null   float64
#  12  Largura               4519 non-null   float64
#  13  Profundidade          4519 non-null   float64
# ...

# %%
clean_df_data = clean

# %%
import re

# %%
regex = re.compile(r'[5679]{1}[0-9]{5}')

# df[df.name.str.match(regex)

# %%
# clean_df_data.Price.apply(lambda x: str(x).replace(',', '')).astype(float)
# df_data[df_data.category == 'Economics'].sort_values('year')[:3]
# clean_df_data[clean_df_data['Código'].str.match(regex)]
clean2 = clean_df_data[clean_df_data['Código'].str.len() == 6]

# %%
clean2 = clean2[clean2['Código'].str.match(regex)]

# %%
msno.matrix(clean2)
# Out:
# <AxesSubplot:>

# %%
msno.bar(clean2, log=True)
# Out:
# C:\github\code-description-manager\venv\lib\site-packages\missingno\missingno.py:271: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels([int(n * len(df)) for n in ax1.get_yticks()], fontsize=fontsize)
# <AxesSubplot:>

# %%
clean2[clean2['Família de Produto'].isna()]
# Out:
#      Situação                                          Descrição  Código  \
# 1443    Ativo       ANULAÇÃO DE VALORES DO CONHECIMENTO DE FRETE  772466
# 1997    Ativo                           TRATAMENTO BANHO DE OURO  771911
# 2013    Ativo                              CORTE LASER (SERVIÇO)  771895
# 2041    Ativo                      TRATAMENTO ANODIZAÇÃO NATURAL  771867
# 2042    Ativo                         TRATAMENTO ELETROPOLIMENTO  771866
# 2043    Ativo                      TRATAMENTO ANODIZACAO VIOLETA  771865
# 3510    Ativo  PARAFUSO SEXTAVADO 5/16 x 75 - ZINCADO (PEDESTAL)  770141
# 4118    Ativo                           FITA DESSOLDADORA HIKARI  550080
# 4140    Ativo                    EPI - LUVA NITRILICA AZUL TAM G  550021
# 4143    Ativo                     EPI - LUVA PU TAMANHO Nº 8 (M)  550018
# 4144    Ativo                     EPI - LUVA PU TAMANHO Nº 7 (P)  550017
# 4156    Ativo                            OLEO DIESEL B S10 COMUM  550005
#
# ...

# %%
clean2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3765 entries, 261 to 4160
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Situação              3765 non-null   object
#  1   Descrição             3765 non-null   object
#  2   Código                3765 non-null   object
#  3   Família de Produto    3753 non-null   object
#  4   Código NCM            3765 non-null   object
#  5   Estoque Disponível    3765 non-null   float64
#  6   Unidade               3765 non-null   object
#  7   Custo Médio Contábil  3765 non-null   float64
#  8   Estoque Mínimo        3765 non-null   int64
#  9   Peso Líquido          3765 non-null   float64
#  10  Peso Bruto            3765 non-null   float64
#  11  Altura                3765 non-null   float64
#  12  Largura               3765 non-null   float64
#  13  Profundidade          3765 non-null   float64
# ...

# %%
clean2[clean2['Situação']=='Inativo']
# Out:
#      Situação                                          Descrição  Código  \
# 271   Inativo               BOMBA DE INFUSÃO SP750 - VETERINÁRIA  990459
# 273   Inativo                     "PROTOTIPO" ULTRASSOM DENTÁRIO  990457
# 305   Inativo          *PROTÓTIPO*  BLENDER - MISTURADOR AR X O2  990422
# 307   Inativo  TESOURA PARA TOSA CURVA 6,5 PRESICION - VETERI...  990420
# 308   Inativo  TESOURA PARA TOSA RETA 6,5 PRESICION - VETERIN...  990419
# ...       ...                                                ...     ...
# 4108  Inativo  (INATIVO) - FERRAMENTA P/ TORNEAR INT MD PVD C...  550090
# 4114  Inativo          (INATIVO) -RODA DE ALGODAO 06 COM COSTURA  550084
# 4116  Inativo                             CHAVE ALLEN 3MM GEDORE  550082
# 4119  Inativo      (INATIVO) - BROCA HSCO 3,30 MM Ti (5XD) C/TiN  550077
# 4122  Inativo          (INATIVO) - BROCA MD PVD MSE0150SB VP15TF  550074
#
#                   Família de Produto  Código NCM  Estoque Disponível  \
# ...
